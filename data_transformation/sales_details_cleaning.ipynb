# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ## Extract data from SQL server

# %%
# Extract the source data from the Bronze layer in SQL Server

server = 'mohamedibrahim'
database = 'DataWarehouse'

connection_string = (
    f'mssql+pyodbc://mohamedibrahim/DataWarehouse'
    '?driver=ODBC+Driver+17+for+SQL+Server'
    '&Trusted_Connection=yes'
)
engine = create_engine(connection_string)

query = "SELECT * FROM bronze.crm_sales_details"
df = pd.read_sql(query, engine)

# %% [markdown]
# ## Data overview

# %%
df.head()
# Out:
#   sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  sls_due_dt  \
# 0     SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05  2011-01-10
# 1     SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05  2011-01-10
# 2     SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05  2011-01-10
# 3     SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05  2011-01-10
# 4     SO43701  BK-M82S-44        11003   2010-12-29  2011-01-05  2011-01-10
#
#    sls_sales  sls_quantity  sls_price
# 0     3578.0             1     3578.0
# 1     3400.0             1     3400.0
# 2     3400.0             1     3400.0
# 3      699.0             1      699.0
# 4     3400.0             1     3400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sls_ord_num   60398 non-null  object
#  1   sls_prd_key   60398 non-null  object
#  2   sls_cust_id   60398 non-null  int64
#  3   sls_order_dt  60379 non-null  object
#  4   sls_ship_dt   60398 non-null  object
#  5   sls_due_dt    60398 non-null  object
#  6   sls_sales     60390 non-null  float64
#  7   sls_quantity  60398 non-null  int64
#  8   sls_price     60391 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# sls_ord_num      0
# sls_prd_key      0
# sls_cust_id      0
# sls_order_dt    19
# sls_ship_dt      0
# sls_due_dt       0
# sls_sales        8
# sls_quantity     0
# sls_price        7
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Checks each object column for unwanted spaces (leading spaces, trailing spaces, multiple spaces)
for col in df.select_dtypes(include='object').columns:
    has_unwanted_spaces = False
    
    # Iterate through non-null values and check each one
    for value in df[col][df[col].notna()]:
        # Convert to string and check for unwanted spaces
        str_value = str(value)
        # Check for leading/trailing spaces or multiple consecutive spaces
        if str_value != str_value.strip() or '  ' in str_value:
            has_unwanted_spaces = True
            break
    
    if has_unwanted_spaces:
        print(f"Unwanted spaces found in column: {col}")

# %% [markdown]
# ## Data Inspection & Cleaning

# %% [markdown]
# #### Column "sls_ord_num"

# %%
df["sls_ord_num"].unique().tolist()
# Out:
# ['SO43697',
#  'SO43698',
#  'SO43699',
#  'SO43700',
#  'SO43701',
#  'SO43702',
#  'SO43703',
#  'SO43704',
#  'SO43705',
#  'SO43706',
#  'SO43707',
#  'SO43708',
#  'SO43709',
#  'SO43710',
#  'SO43711',
#  'SO43712',
#  'SO43713',
#  'SO43714',
#  'SO43715',
#  'SO43716',
#  'SO43717',
#  'SO43718',
#  'SO43719',
#  'SO43720',
#  'SO43721',
#  'SO43722',
#  'SO43723',
#  'SO43724',
#  'SO43725',
#  'SO43726',
#  'SO43727',
#  'SO43728',
#  'SO43729',
#  'SO43730',
#  'SO43731',
#  'SO43732',
#  'SO43733',
#  'SO43734',
#  'SO43735',
#  'SO43736',
#  'SO43737',
#  'SO43738',
#  'SO43739',
#  'SO43740',
#  'SO43741',
#  'SO43742',
#  'SO43743',
#  'SO43744',
#  'SO43745',
#  'SO43746',
#  'SO43747',
#  'SO43748',
#  'SO43749',
#  'SO43750',
#  'SO43751',
#  'SO43752',
#  'SO43753',
#  'SO43754',
#  'SO43755',
#  'SO43756',
#  'SO43757',
#  'SO43758',
#  'SO43759',
#  'SO43760',
#  'SO43761',
#  'SO43762',
#  'SO43763',
#  'SO43764',
#  'SO43765',
#  'SO43766',
#  'SO43767',
#  'SO43768',
#  'SO43769',
#  'SO43770',
#  'SO43771',
#  'SO43772',
#  'SO43773',
#  'SO43774',
#  'SO43775',
#  'SO43776',
#  'SO43777',
#  'SO43778',
#  'SO43779',
#  'SO43780',
#  'SO43781',
#  'SO43782',
#  'SO43783',
#  'SO43784',
#  'SO43785',
#  'SO43786',
#  'SO43787',
#  'SO43788',
#  'SO43789',
#  'SO43790',
#  'SO43791',
#  'SO43792',
#  'SO43793',
#  'SO43794',
#  'SO43795',
#  'SO43796',
#  'SO43797',
#  'SO43798',
#  'SO43799',
#  'SO43800',
#  'SO43801',
#  'SO43802',
#  'SO43803',
#  'SO43804',
#  'SO43805',
#  'SO43806',
#  'SO43807',
#  'SO43808',
#  'SO43809',
#  'SO43810',
#  'SO43811',
#  'SO43812',
#  'SO43813',
#  'SO43814',
#  'SO43815',
#  'SO43816',
#  'SO43817',
#  'SO43818',
#  'SO43819',
#  'SO43820',
#  'SO43821',
#  'SO43822',
#  'SO43823',
#  'SO43824',
#  'SO43825',
#  'SO43826',
#  'SO43827',
#  'SO43828',
#  'SO43829',
#  'SO43830',
#  'SO43831',
#  'SO43832',
#  'SO43833',
#  'SO43834',
#  'SO43835',
#  'SO43836',
#  'SO43837',
#  'SO43838',
#  'SO43839',
#  'SO43840',
#  'SO43841',
#  'SO43842',
#  'SO43918',
#  'SO43919',
#  'SO43920',
#  'SO43921',
#  'SO43922',
#  'SO43923',
#  'SO43924',
#  'SO43925',
#  'SO43926',
#  'SO43927',
#  'SO43928',
#  'SO43929',
#  'SO43930',
#  'SO43931',
#  'SO43932',
#  'SO43933',
#  'SO43934',
#  'SO43935',
#  'SO43936',
#  'SO43937',
#  'SO43938',
#  'SO43939',
#  'SO43940',
#  'SO43941',
#  'SO43942',
#  'SO43943',
#  'SO43944',
#  'SO43945',
#  'SO43946',
#  'SO43947',
#  'SO43948',
#  'SO43949',
#  'SO43950',
#  'SO43951',
#  'SO43952',
#  'SO43953',
#  'SO43954',
#  'SO43955',
#  'SO43956',
#  'SO43957',
#  'SO43958',
#  'SO43959',
#  'SO43960',
#  'SO43961',
#  'SO43962',
#  'SO43963',
#  'SO43964',
#  'SO43965',
#  'SO43966',
#  'SO43967',
#  'SO43968',
#  'SO43969',
#  'SO43970',
#  'SO43971',
#  'SO43972',
#  'SO43973',
#  'SO43974',
#  'SO43975',
#  'SO43976',
#  'SO43977',
#  'SO43978',
#  'SO43979',
#  'SO43980',
#  'SO43981',
#  'SO43982',
#  'SO43983',
#  'SO43984',
#  'SO43985',
#  'SO43986',
#  'SO43987',
#  'SO43988',
#  'SO43989',
#  'SO43990',
#  'SO43991',
#  'SO43992',
#  'SO43993',
#  'SO43994',
#  'SO43995',
#  'SO43996',
#  'SO43997',
#  'SO43998',
#  'SO43999',
#  'SO44000',
#  'SO44001',
#  'SO44002',
#  'SO44003',
#  'SO44004',
#  'SO44005',
#  'SO44006',
#  'SO44007',
#  'SO44008',
#  'SO44009',
#  'SO44010',
#  'SO44011',
#  'SO44012',
#  'SO44013',
#  'SO44014',
#  'SO44015',
#  'SO44016',
#  'SO44017',
#  'SO44018',
#  'SO44019',
#  'SO44020',
#  'SO44021',
#  'SO44022',
#  'SO44023',
#  'SO44024',
#  'SO44025',
#  'SO44026',
#  'SO44027',
#  'SO44028',
#  'SO44029',
#  'SO44030',
#  'SO44031',
#  'SO44032',
#  'SO44033',
#  'SO44034',
#  'SO44035',
#  'SO44036',
#  'SO44037',
#  'SO44038',
#  'SO44039',
#  'SO44040',
#  'SO44041',
#  'SO44042',
#  'SO44043',
#  'SO44044',
#  'SO44045',
#  'SO44046',
#  'SO44047',
#  'SO44048',
#  'SO44049',
#  'SO44050',
#  'SO44051',
#  'SO44052',
#  'SO44053',
#  'SO44054',
#  'SO44055',
#  'SO44056',
#  'SO44057',
#  'SO44058',
#  'SO44059',
#  'SO44060',
#  'SO44061',
#  'SO44062',
#  'SO44063',
#  'SO44064',
#  'SO44065',
#  'SO44066',
#  'SO44067',
#  'SO44068',
#  'SO44069',
#  'SO44070',
#  'SO44071',
#  'SO44072',
#  'SO44073',
#  'SO44134',
#  'SO44135',
#  'SO44136',
#  'SO44137',
#  'SO44138',
#  'SO44139',
#  'SO44140',
#  'SO44141',
#  'SO44142',
#  'SO44143',
#  'SO44144',
#  'SO44145',
#  'SO44146',
#  'SO44147',
#  'SO44148',
#  'SO44149',
#  'SO44150',
#  'SO44151',
#  'SO44152',
#  'SO44153',
#  'SO44154',
#  'SO44155',
#  'SO44156',
#  'SO44157',
#  'SO44158',
#  'SO44159',
#  'SO44160',
#  'SO44161',
#  'SO44162',
#  'SO44163',
#  'SO44164',
#  'SO44165',
#  'SO44166',
#  'SO44167',
#  'SO44168',
#  'SO44169',
#  'SO44170',
#  'SO44171',
#  'SO44172',
#  'SO44173',
#  'SO44174',
#  'SO44175',
#  'SO44176',
#  'SO44177',
#  'SO44178',
#  'SO44179',
#  'SO44180',
#  'SO44181',
#  'SO44182',
#  'SO44183',
#  'SO44184',
#  'SO44185',
#  'SO44186',
#  'SO44187',
#  'SO44188',
#  'SO44189',
#  'SO44190',
#  'SO44191',
#  'SO44192',
#  'SO44193',
#  'SO44194',
#  'SO44195',
#  'SO44196',
#  'SO44197',
#  'SO44198',
#  'SO44199',
#  'SO44200',
#  'SO44201',
#  'SO44202',
#  'SO44203',
#  'SO44204',
#  'SO44205',
#  'SO44206',
#  'SO44207',
#  'SO44208',
#  'SO44209',
#  'SO44210',
#  'SO44211',
#  'SO44212',
#  'SO44213',
#  'SO44214',
#  'SO44215',
#  'SO44216',
#  'SO44217',
#  'SO44218',
#  'SO44219',
#  'SO44220',
#  'SO44221',
#  'SO44222',
#  'SO44223',
#  'SO44224',
#  'SO44225',
#  'SO44226',
#  'SO44227',
#  'SO44228',
#  'SO44229',
#  'SO44230',
#  'SO44231',
#  'SO44232',
#  'SO44233',
#  'SO44234',
#  'SO44235',
#  'SO44236',
#  'SO44237',
#  'SO44238',
#  'SO44239',
#  'SO44240',
#  'SO44241',
#  'SO44242',
#  'SO44243',
#  'SO44244',
#  'SO44245',
#  'SO44246',
#  'SO44247',
#  'SO44248',
#  'SO44249',
#  'SO44250',
#  'SO44251',
#  'SO44252',
#  'SO44253',
#  'SO44254',
#  'SO44255',
#  'SO44256',
#  'SO44257',
#  'SO44258',
#  'SO44259',
#  'SO44260',
#  'SO44261',
#  'SO44262',
#  'SO44263',
#  'SO44264',
#  'SO44265',
#  'SO44266',
#  'SO44267',
#  'SO44268',
#  'SO44269',
#  'SO44270',
#  'SO44271',
#  'SO44272',
#  'SO44273',
#  'SO44274',
#  'SO44275',
#  'SO44276',
#  'SO44277',
#  'SO44278',
#  'SO44279',
#  'SO44320',
#  'SO44321',
#  'SO44322',
#  'SO44323',
#  'SO44324',
#  'SO44325',
#  'SO44326',
#  'SO44327',
#  'SO44328',
#  'SO44329',
#  'SO44330',
#  'SO44331',
#  'SO44332',
#  'SO44333',
#  'SO44334',
#  'SO44335',
#  'SO44336',
#  'SO44337',
#  'SO44338',
#  'SO44339',
#  'SO44340',
#  'SO44341',
#  'SO44342',
#  'SO44343',
#  'SO44344',
#  'SO44345',
#  'SO44346',
#  'SO44347',
#  'SO44348',
#  'SO44349',
#  'SO44350',
#  'SO44351',
#  'SO44352',
#  'SO44353',
#  'SO44354',
#  'SO44355',
#  'SO44356',
#  'SO44357',
#  'SO44358',
#  'SO44359',
#  'SO44360',
#  'SO44361',
#  'SO44362',
#  'SO44363',
#  'SO44364',
#  'SO44365',
#  'SO44366',
#  'SO44367',
#  'SO44368',
#  'SO44369',
#  'SO44370',
#  'SO44371',
#  'SO44372',
#  'SO44373',
#  'SO44374',
#  'SO44375',
#  'SO44376',
#  'SO44377',
#  'SO44378',
#  'SO44379',
#  'SO44380',
#  'SO44381',
#  'SO44382',
#  'SO44383',
#  'SO44384',
#  'SO44385',
#  'SO44386',
#  'SO44387',
#  'SO44388',
#  'SO44389',
#  'SO44390',
#  'SO44391',
#  'SO44392',
#  'SO44393',
#  'SO44394',
#  'SO44395',
#  'SO44396',
#  'SO44397',
#  'SO44398',
#  'SO44399',
#  'SO44400',
#  'SO44401',
#  'SO44402',
#  'SO44403',
#  'SO44404',
#  'SO44405',
#  'SO44406',
#  'SO44407',
#  'SO44408',
#  'SO44409',
#  'SO44410',
#  'SO44411',
#  'SO44412',
#  'SO44413',
#  'SO44414',
#  'SO44415',
#  'SO44416',
#  'SO44417',
#  'SO44418',
#  'SO44419',
#  'SO44420',
#  'SO44421',
#  'SO44422',
#  'SO44423',
#  'SO44424',
#  'SO44425',
#  'SO44426',
#  'SO44427',
#  'SO44428',
#  'SO44429',
#  'SO44430',
#  'SO44431',
#  'SO44432',
#  'SO44433',
#  'SO44434',
#  'SO44435',
#  'SO44436',
#  'SO44437',
#  'SO44438',
#  'SO44439',
#  'SO44440',
#  'SO44441',
#  'SO44442',
#  'SO44443',
#  'SO44444',
#  'SO44445',
#  'SO44446',
#  'SO44447',
#  'SO44448',
#  'SO44449',
#  'SO44450',
#  'SO44451',
#  'SO44452',
#  'SO44453',
#  'SO44454',
#  'SO44455',
#  'SO44456',
#  'SO44457',
#  'SO44458',
#  'SO44459',
#  'SO44460',
#  'SO44461',
#  'SO44462',
#  'SO44463',
#  'SO44464',
#  'SO44465',
#  'SO44466',
#  'SO44467',
#  'SO44468',
#  'SO44469',
#  'SO44470',
#  'SO44471',
#  'SO44472',
#  'SO44473',
#  'SO44474',
#  'SO44475',
#  'SO44476',
#  'SO44477',
#  'SO44478',
#  'SO44479',
#  'SO44480',
#  'SO44571',
#  'SO44572',
#  'SO44573',
#  'SO44574',
#  'SO44575',
#  'SO44576',
#  'SO44577',
#  'SO44578',
#  'SO44579',
#  'SO44580',
#  'SO44581',
#  'SO44582',
#  'SO44583',
#  'SO44584',
#  'SO44585',
#  'SO44586',
#  'SO44587',
#  'SO44588',
#  'SO44589',
#  'SO44590',
#  'SO44591',
#  'SO44592',
#  'SO44593',
#  'SO44594',
#  'SO44595',
#  'SO44596',
#  'SO44597',
#  'SO44598',
#  'SO44599',
#  'SO44600',
#  'SO44601',
#  'SO44602',
#  'SO44603',
#  'SO44604',
#  'SO44605',
#  'SO44606',
#  'SO44607',
#  'SO44608',
#  'SO44609',
#  'SO44610',
#  'SO44611',
#  'SO44612',
#  'SO44613',
#  'SO44614',
#  'SO44615',
#  'SO44616',
#  'SO44617',
#  'SO44618',
#  'SO44619',
#  'SO44620',
#  'SO44621',
#  'SO44622',
#  'SO44623',
#  'SO44624',
#  'SO44625',
#  'SO44626',
#  'SO44627',
#  'SO44628',
#  'SO44629',
#  'SO44630',
#  'SO44631',
#  'SO44632',
#  'SO44633',
#  'SO44634',
#  'SO44635',
#  'SO44636',
#  'SO44637',
#  'SO44638',
#  'SO44639',
#  'SO44640',
#  'SO44641',
#  'SO44642',
#  'SO44643',
#  'SO44644',
#  'SO44645',
#  'SO44646',
#  'SO44647',
#  'SO44648',
#  'SO44649',
#  'SO44650',
#  'SO44651',
#  'SO44652',
#  'SO44653',
#  'SO44654',
#  'SO44655',
#  'SO44656',
#  'SO44657',
#  'SO44658',
#  'SO44659',
#  'SO44660',
#  'SO44661',
#  'SO44662',
#  'SO44663',
#  'SO44664',
#  'SO44665',
#  'SO44666',
#  'SO44667',
#  'SO44668',
#  'SO44669',
#  'SO44670',
#  'SO44671',
#  'SO44672',
#  'SO44673',
#  'SO44674',
#  'SO44675',
#  'SO44676',
#  'SO44677',
#  'SO44678',
#  'SO44679',
#  'SO44680',
#  'SO44681',
#  'SO44682',
#  'SO44683',
#  'SO44684',
#  'SO44685',
#  'SO44686',
#  'SO44687',
#  'SO44688',
#  'SO44689',
#  'SO44690',
#  'SO44691',
#  'SO44692',
#  'SO44693',
#  'SO44694',
#  'SO44695',
#  'SO44696',
#  'SO44697',
#  'SO44698',
#  'SO44699',
#  'SO44700',
#  'SO44701',
#  'SO44702',
#  'SO44703',
#  'SO44704',
#  'SO44705',
#  'SO44706',
#  'SO44707',
#  'SO44708',
#  'SO44709',
#  'SO44710',
#  'SO44711',
#  'SO44712',
#  'SO44713',
#  'SO44714',
#  'SO44715',
#  'SO44716',
#  'SO44717',
#  'SO44718',
#  'SO44719',
#  'SO44720',
#  'SO44721',
#  'SO44722',
#  'SO44723',
#  'SO44724',
#  'SO44725',
#  'SO44726',
#  'SO44727',
#  'SO44728',
#  'SO44729',
#  'SO44730',
#  'SO44731',
#  'SO44732',
#  'SO44733',
#  'SO44734',
#  'SO44735',
#  'SO44736',
#  'SO44737',
#  'SO44738',
#  'SO44739',
#  'SO44803',
#  'SO44804',
#  'SO44805',
#  'SO44806',
#  'SO44807',
#  'SO44808',
#  'SO44809',
#  'SO44810',
#  'SO44811',
#  'SO44812',
#  'SO44813',
#  'SO44814',
#  'SO44815',
#  'SO44816',
#  'SO44817',
#  'SO44818',
#  'SO44819',
#  'SO44820',
#  'SO44821',
#  'SO44822',
#  'SO44823',
#  'SO44824',
#  'SO44825',
#  'SO44826',
#  'SO44827',
#  'SO44828',
#  'SO44829',
#  'SO44830',
#  'SO44831',
#  'SO44832',
#  'SO44833',
#  'SO44834',
#  'SO44835',
#  'SO44836',
#  'SO44837',
#  'SO44838',
#  'SO44839',
#  'SO44840',
#  'SO44841',
#  'SO44842',
#  'SO44843',
#  'SO44844',
#  'SO44845',
#  'SO44846',
#  'SO44847',
#  'SO44848',
#  'SO44849',
#  'SO44850',
#  'SO44851',
#  'SO44852',
#  'SO44853',
#  'SO44854',
#  'SO44855',
#  'SO44856',
#  'SO44857',
#  'SO44858',
#  'SO44859',
#  'SO44860',
#  'SO44861',
#  'SO44862',
#  'SO44863',
#  'SO44864',
#  'SO44865',
#  'SO44866',
#  'SO44867',
#  'SO44868',
#  'SO44869',
#  'SO44870',
#  'SO44871',
#  'SO44872',
#  'SO44873',
#  'SO44874',
#  'SO44875',
#  'SO44876',
#  'SO44877',
#  'SO44878',
#  'SO44879',
#  'SO44880',
#  'SO44881',
#  'SO44882',
#  'SO44883',
#  'SO44884',
#  'SO44885',
#  'SO44886',
#  'SO44887',
#  'SO44888',
#  'SO44889',
#  'SO44890',
#  'SO44891',
#  'SO44892',
#  'SO44893',
#  'SO44894',
#  'SO44895',
#  'SO44896',
#  'SO44897',
#  'SO44898',
#  'SO44899',
#  'SO44900',
#  'SO44901',
#  'SO44902',
#  'SO44903',
#  'SO44904',
#  'SO44905',
#  'SO44906',
#  'SO44907',
#  'SO44908',
#  'SO44909',
#  'SO44910',
#  'SO44911',
#  'SO44912',
#  'SO44913',
#  'SO44914',
#  'SO44915',
#  'SO44916',
#  'SO44917',
#  'SO44918',
#  'SO44919',
#  'SO44920',
#  'SO44921',
#  'SO44922',
#  'SO44923',
#  'SO44924',
#  'SO44925',
#  'SO44926',
#  'SO44927',
#  'SO44928',
#  'SO44929',
#  'SO44930',
#  'SO44931',
#  'SO44932',
#  'SO44933',
#  'SO44934',
#  'SO44935',
#  'SO44936',
#  'SO44937',
#  'SO44938',
#  'SO44939',
#  'SO44940',
#  'SO44941',
#  'SO44942',
#  'SO44943',
#  'SO44944',
#  'SO44945',
#  'SO44946',
#  'SO44947',
#  'SO44948',
#  'SO44949',
#  'SO44950',
#  'SO44951',
#  'SO44952',
#  'SO44953',
#  'SO44954',
#  'SO44955',
#  'SO44956',
#  'SO44957',
#  'SO44958',
#  'SO44959',
#  'SO44960',
#  'SO44961',
#  'SO44962',
#  'SO44963',
#  'SO44964',
#  'SO44965',
#  'SO44966',
#  'SO44967',
#  'SO44968',
#  'SO44969',
#  'SO44970',
#  'SO44971',
#  'SO44972',
#  'SO44973',
#  'SO44974',
#  'SO44975',
#  'SO44976',
#  'SO44977',
#  'SO44978',
#  'SO44979',
#  'SO44980',
#  'SO44981',
#  'SO44982',
#  'SO44983',
#  'SO44984',
#  'SO44985',
#  'SO44986',
#  'SO44987',
#  'SO44988',
#  'SO44989',
#  'SO44990',
#  'SO44991',
#  'SO44992',
#  'SO44993',
#  'SO44994',
#  'SO44995',
#  'SO44996',
#  'SO44997',
#  'SO44998',
#  'SO44999',
#  'SO45000',
#  'SO45001',
#  'SO45002',
#  'SO45003',
#  'SO45004',
#  'SO45005',
#  'SO45006',
#  'SO45007',
#  'SO45008',
#  'SO45009',
#  'SO45010',
#  'SO45011',
#  'SO45012',
#  'SO45013',
#  'SO45014',
#  'SO45015',
#  'SO45016',
#  'SO45017',
#  'SO45018',
#  'SO45019',
#  'SO45020',
#  'SO45021',
#  'SO45022',
#  'SO45023',
#  'SO45024',
#  ...]

# %%
df[~df["sls_ord_num"].str.match(r"SO\d{5}", na=False)]
# Out:
# Empty DataFrame
# Columns: [sls_ord_num, sls_prd_key, sls_cust_id, sls_order_dt, sls_ship_dt, sls_due_dt, sls_sales, sls_quantity, sls_price]
# Index: []

# %% [markdown]
# #### Column "sls_prd_key"

# %%
df['sls_prd_key'].unique().tolist()
# Out:
# ['BK-R93R-62',
#  'BK-M82S-44',
#  'BK-R50B-62',
#  'BK-R93R-44',
#  'BK-M82B-48',
#  'BK-M82S-38',
#  'BK-R93R-48',
#  'BK-R50R-52',
#  'BK-R93R-52',
#  'BK-R93R-56',
#  'BK-R50B-58',
#  'BK-M82B-44',
#  'BK-M82S-48',
#  'BK-M82S-42',
#  'BK-R50R-44',
#  'BK-R50B-52',
#  'BK-R50R-48',
#  'BK-R50B-44',
#  'BK-M82B-38',
#  'BK-M82B-42',
#  'BK-R50R-62',
#  'BK-R50R-60',
#  'BK-R50B-60',
#  'BK-R50R-58',
#  'BK-R50B-48',
#  'BK-R64Y-42',
#  'BK-R89R-58',
#  'BK-R89B-44',
#  'BK-M68B-46',
#  'BK-M68B-38',
#  'BK-M68S-42',
#  'BK-R64Y-38',
#  'BK-R89B-52',
#  'BK-R89B-58',
#  'BK-R89R-48',
#  'BK-R89R-44',
#  'BK-R89R-52',
#  'BK-R89B-48',
#  'BK-M68S-38',
#  'BK-R64Y-44',
#  'BK-M68S-46',
#  'BK-M68B-42',
#  'BK-R64Y-40',
#  'BK-R64Y-48',
#  'BC-R205',
#  'BK-T44U-46',
#  'HL-U509',
#  'BC-M005',
#  'WB-H098',
#  'TI-R982',
#  'TT-R982',
#  'ST-1401',
#  'HL-U509-R',
#  'LJ-0192-M',
#  'BK-R79Y-42',
#  'LJ-0192-L',
#  'TI-M823',
#  'TT-M928',
#  'HL-U509-B',
#  'BK-T18Y-58',
#  'TI-T723',
#  'TT-T092',
#  'BK-T79U-46',
#  'BK-R19B-52',
#  'TI-R092',
#  'GL-H102-L',
#  'BK-R79Y-40',
#  'TI-R628',
#  'FE-6654',
#  'BK-M38S-40',
#  'TI-M602',
#  'BK-R19B-44',
#  'CA-1098',
#  'BK-T44U-50',
#  'SJ-0194-M',
#  'BK-M18S-44',
#  'GL-H102-M',
#  'BK-T18U-54',
#  'SO-R809-L',
#  'SJ-0194-S',
#  'BK-T79U-60',
#  'BK-R19B-58',
#  'PK-7098',
#  'BK-M18B-40',
#  'BK-T44U-60',
#  'GL-H102-S',
#  'SJ-0194-L',
#  'BK-R19B-48',
#  'HY-1023-70',
#  'BK-R79Y-48',
#  'BK-T79Y-50',
#  'VE-C304-S',
#  'BK-T79U-50',
#  'BK-M18S-42',
#  'TI-M267',
#  'CL-9009',
#  'BK-T79U-54',
#  'SJ-0194-X',
#  'VE-C304-L',
#  'LJ-0192-S',
#  'BK-T79Y-60',
#  'BK-R79Y-44',
#  'VE-C304-M',
#  'BK-T18Y-50',
#  'BK-M18S-40',
#  'BK-M38S-38',
#  'BK-M18B-44',
#  'BK-M18B-48',
#  'BK-T79Y-46',
#  'BK-M38S-42',
#  'LJ-0192-X',
#  'SO-R809-M',
#  'BK-T44U-54',
#  'BK-M38S-46',
#  'BK-M18B-42',
#  'RA-H123',
#  'BK-T18U-50',
#  'SH-W890-M',
#  'BK-T18U-58',
#  'BK-M18B-52',
#  'SH-W890-L',
#  'BK-T18U-44',
#  'BK-M18S-48',
#  'BK-M18S-52',
#  'SH-W890-S',
#  'BK-T18Y-62',
#  'BK-T79Y-54',
#  'BK-T18Y-54',
#  'BK-T18Y-44',
#  'BK-T18U-62']

# %% [markdown]
# #### Column "sls_cust_id"

# %%
df["sls_cust_id"].unique().tolist()
# Out:
# [21768,
#  28389,
#  25863,
#  14501,
#  11003,
#  27645,
#  16624,
#  14700,
#  28625,
#  26643,
#  13774,
#  29410,
#  28665,
#  25910,
#  14614,
#  18273,
#  11126,
#  12307,
#  14697,
#  28661,
#  18251,
#  18214,
#  12285,
#  28673,
#  14634,
#  18242,
#  18252,
#  18202,
#  12383,
#  28829,
#  29011,
#  18452,
#  11365,
#  13836,
#  20552,
#  29126,
#  22732,
#  28988,
#  18695,
#  18281,
#  11444,
#  12321,
#  14777,
#  28827,
#  28853,
#  25972,
#  25975,
#  18486,
#  18488,
#  18694,
#  18309,
#  12308,
#  25973,
#  28997,
#  14643,
#  18337,
#  29467,
#  28804,
#  28842,
#  25952,
#  18338,
#  18465,
#  13808,
#  14138,
#  28825,
#  28857,
#  18335,
#  14140,
#  29058,
#  29139,
#  28845,
#  18334,
#  11445,
#  28418,
#  17996,
#  19417,
#  22299,
#  29128,
#  19874,
#  29004,
#  26692,
#  14651,
#  18484,
#  18487,
#  18495,
#  18693,
#  18288,
#  18457,
#  18467,
#  11364,
#  11372,
#  11443,
#  14793,
#  28852,
#  18700,
#  18301,
#  11363,
#  29111,
#  28828,
#  18004,
#  29048,
#  29056,
#  29136,
#  28807,
#  28833,
#  18470,
#  18496,
#  18703,
#  18296,
#  18308,
#  14833,
#  29108,
#  28821,
#  28838,
#  11351,
#  11381,
#  28847,
#  22267,
#  28856,
#  25943,
#  25951,
#  25964,
#  18696,
#  18307,
#  11353,
#  14778,
#  12332,
#  13829,
#  18284,
#  11359,
#  13822,
#  14832,
#  19415,
#  29032,
#  28840,
#  25969,
#  25976,
#  28966,
#  18468,
#  18491,
#  18461,
#  18463,
#  13842,
#  29466,
#  29017,
#  14648,
#  18489,
#  18277,
#  18336,
#  28830,
#  18493,
#  25706,
#  11448,
#  14843,
#  12398,
#  29110,
#  28849,
#  18303,
#  18276,
#  14771,
#  12333,
#  29044,
#  22251,
#  28851,
#  28993,
#  18490,
#  18697,
#  18701,
#  25568,
#  25707,
#  25710,
#  11357,
#  11446,
#  12395,
#  29474,
#  28835,
#  28843,
#  25955,
#  28859,
#  28990,
#  25709,
#  11449,
#  22247,
#  20173,
#  29019,
#  22373,
#  29060,
#  28831,
#  25974,
#  14647,
#  14649,
#  18458,
#  14794,
#  19365,
#  22713,
#  28820,
#  28989,
#  29016,
#  18482,
#  14776,
#  28823,
#  28824,
#  29010,
#  14652,
#  18469,
#  18699,
#  18462,
#  29132,
#  22252,
#  29008,
#  18692,
#  25708,
#  12323,
#  17999,
#  28854,
#  14645,
#  18698,
#  18464,
#  11368,
#  28805,
#  28841,
#  25970,
#  28870,
#  14646,
#  18485,
#  18297,
#  18302,
#  13844,
#  29059,
#  29106,
#  28844,
#  12373,
#  14137,
#  14831,
#  19387,
#  28869,
#  22268,
#  14650,
#  18483,
#  25705,
#  11360,
#  14770,
#  28826,
#  18494,
#  18691,
#  18332,
#  11358,
#  11447,
#  13807,
#  29475,
#  ...]

# %%
df[~df["sls_cust_id"].astype(str).str.match(r"\d{5}")]
# Out:
# Empty DataFrame
# Columns: [sls_ord_num, sls_prd_key, sls_cust_id, sls_order_dt, sls_ship_dt, sls_due_dt, sls_sales, sls_quantity, sls_price]
# Index: []

# %% [markdown]
# #### Column "sls_order_dt" & "sls_ship_dt" & "sls_due_dt"

# %%
df['sls_order_dt'] = pd.to_datetime(df['sls_order_dt'], format='%Y%m%d')
df['sls_ship_dt'] = pd.to_datetime(df['sls_ship_dt'], format='%Y%m%d')
df['sls_due_dt'] = pd.to_datetime(df['sls_due_dt'], format='%Y%m%d')

# %%
df["shipping_days"] = (df["sls_ship_dt"] - df["sls_order_dt"]).dt.days

# %%
df["shipping_days"].unique()
# Out:
# array([ 7., nan])

# %%
df["sls_order_dt"] = df["sls_order_dt"].fillna(df["sls_ship_dt"] - pd.Timedelta(days=7))

# %%
df = df.drop(columns=["shipping_days"])

# %% [markdown]
# #### Columns "sls_sales" & "sls_quantity" & "sls_price"

# %%
mismatch_rows = df[df["sls_sales"] != df["sls_quantity"] * df["sls_price"]]
print(mismatch_rows)
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 5658      SO51259     WB-H098        11433   2013-01-01  2013-01-08
# 5770      SO51298     WB-H098        27949   2013-01-04  2013-01-11
# 6018      SO51387   HL-U509-B        11942   2013-01-09  2013-01-16
# 6271      SO51479     BC-R205        16687   2013-01-16  2013-01-23
# 6273      SO51479     HL-U509        16687   2013-01-16  2013-01-23
# 6997      SO51942     BC-M005        11223   2013-01-29  2013-02-05
# 7567      SO52187     CL-9009        18110   2013-02-03  2013-02-10
# 20142     SO57804  BK-M38S-40        16470   2013-05-11  2013-05-18
# 20423     SO57916     TI-M602        23024   2013-05-13  2013-05-20
# 21447     SO58326     FE-6654        12045   2013-05-20  2013-05-27
# 21467     SO58335     TI-M823        13326   2013-05-20  2013-05-27
# 22189     SO58623  BK-R79Y-44        17012   2013-05-25  2013-06-01
# 22655     SO58818     TI-R092        21387   2013-05-28  2013-06-04
# 28826     SO61548   LJ-0192-L        12386   2013-07-05  2013-07-12
# 28827     SO61548     CA-1098        12386   2013-07-05  2013-07-12
# 28858     SO61560     HL-U509        16213   2013-07-05  2013-07-12
# 28860     SO61561     CL-9009        18380   2013-07-05  2013-07-12
# 28861     SO61562     FE-6654        18944   2013-07-05  2013-07-12
# 28884     SO61570     CA-1098        17809   2013-07-05  2013-07-12
# 29058     SO61636     BC-M005        12914   2013-07-06  2013-07-13
# 29659     SO61879   LJ-0192-X        14455   2013-07-10  2013-07-17
# 42557     SO67551     BC-M005        15150   2013-10-01  2013-10-08
# 42941     SO67707     TT-M928        26046   2013-10-04  2013-10-11
# 42942     SO67707   VE-C304-S        26046   2013-10-04  2013-10-11
# 42943     SO67708     TI-M267        26501   2013-10-04  2013-10-11
# 43644     SO67993     PK-7098        17084   2013-10-08  2013-10-15
# 43964     SO68126   LJ-0192-M        13604   2013-10-10  2013-10-17
# 44690     SO68418   GL-H102-M        25277   2013-10-15  2013-10-22
# 45033     SO68551     BC-R205        22691   2013-10-17  2013-10-24
# 45127     SO68588     PK-7098        11318   2013-10-17  2013-10-24
# 45547     SO68745     HL-U509        18262   2013-10-20  2013-10-27
# 45548     SO68745   GL-H102-L        18262   2013-10-20  2013-10-27
# 45882     SO68889     TT-R982        14086   2013-10-22  2013-10-29
# 46329     SO69066   SJ-0194-L        17923   2013-10-24  2013-10-31
# 46697     SO69215     TI-M823        16864   2013-10-26  2013-11-02
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price
# 5658  2013-01-13       10.0             2        NaN
# 5770  2013-01-16       25.0             5        NaN
# 6018  2013-01-21       70.0             2        NaN
# 6271  2013-01-28        9.0             1        NaN
# 6273  2013-01-28       35.0             1        NaN
# 6997  2013-02-10      100.0            10        NaN
# 7567  2013-02-15       16.0             2        NaN
# 20142 2013-05-23      769.0             1     -769.0
# 20423 2013-05-25       30.0             1      -30.0
# 21447 2013-06-01       22.0             1      -22.0
# 21467 2013-06-01       35.0             2       35.0
# 22189 2013-06-06     1701.0             1    -1701.0
# 22655 2013-06-09       21.0             1      -21.0
# 28826 2013-07-17       50.0             2       50.0
# 28827 2013-07-17        NaN             1        9.0
# 28858 2013-07-17        NaN             1       35.0
# 28860 2013-07-17        NaN             1        8.0
# 28861 2013-07-17        NaN             1       22.0
# 28884 2013-07-17      -18.0             1        9.0
# 29058 2013-07-18        0.0             1       10.0
# 29659 2013-07-22       50.0             2       50.0
# 42557 2013-10-13        NaN             1       10.0
# 42941 2013-10-16        5.0             2        5.0
# 42942 2013-10-16       64.0             4       64.0
# 42943 2013-10-16       25.0             3       25.0
# 43644 2013-10-20       40.0             1        2.0
# 43964 2013-10-22        2.0             1       50.0
# 44690 2013-10-27       33.0             1       24.0
# 45033 2013-10-29        8.0             1        9.0
# 45127 2013-10-29        NaN             1        2.0
# 45547 2013-11-01        NaN             1       35.0
# 45548 2013-11-01        NaN             1       24.0
# 45882 2013-11-03        0.0             1        4.0
# 46329 2013-11-05      -54.0             1       54.0
# 46697 2013-11-07      -35.0             1       35.0

# %%
# Rules
# If sales is negative, zero, or null, derive it using quantity and price
# If price is zero or null, calculate it using sales and quantity
# if price is negative, convert it to a positive value

# %%
df["sls_sales"] = df["sls_sales"].abs()
df["sls_price"] = df["sls_price"].abs()

# %%
# Only updates the "sls_sales" column where sls_price is not null
df.loc[df["sls_price"].notnull(), "sls_sales"] = df["sls_quantity"] * df["sls_price"]

# %%
# Selects the rows where sls_price is missing and updates only the "sls_price" column.
df.loc[df["sls_price"].isnull(), "sls_price"] = df["sls_sales"]/df["sls_quantity"]

# %% [markdown]
# ## Load Transformed Data into SQL Server

# %%
# Load the transformed "sales_details" data into the silver layer

server = 'mohamedibrahim'
database = 'DataWarehouse'

connection_string = (
    f'mssql+pyodbc://mohamedibrahim/DataWarehouse'
    '?driver=ODBC+Driver+17+for+SQL+Server'
    '&Trusted_Connection=yes'
)

engine = create_engine(connection_string)

df.to_sql(
    name='crm_sales_details',
    schema='silver',
    con=engine,   
    if_exists='append',
    index=False
)
# Out:
# 51
